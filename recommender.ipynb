# %%
import pandas as pd

# %%
df1 = pd.read_csv("archive/chefmozparking.csv")
df1
# Out:
#      placeID parking_lot
# 0     135111      public
# 1     135110        none
# 2     135109        none
# 3     135108        none
# 4     135107        none
# ..       ...         ...
# 697   132024      street
# 698   132023         fee
# 699   132023      public
# 700   132012      public
# 701   132012      street
#
# [702 rows x 2 columns]

# %%
df2 = pd.read_csv("archive/chefmozaccepts.csv")
df2
# Out:
#       placeID             Rpayment
# 0      135110                 cash
# 1      135110                 VISA
# 2      135110  MasterCard-Eurocard
# 3      135110     American_Express
# 4      135110     bank_debit_cards
# ...       ...                  ...
# 1309   132012          Diners_Club
# 1310   132002  MasterCard-Eurocard
# 1311   132002                 Visa
# 1312   132002     American_Express
# 1313   132002          Diners_Club
#
# [1314 rows x 2 columns]

# %%
merged_df = pd.merge(df1, df2, left_on='placeID', right_on='placeID')
merged_df
# Out:
#       placeID parking_lot             Rpayment
# 0      135110        none                 cash
# 1      135110        none                 VISA
# 2      135110        none  MasterCard-Eurocard
# 3      135110        none     American_Express
# 4      135110        none     bank_debit_cards
# ...       ...         ...                  ...
# 1241   132012      public          Diners_Club
# 1242   132012      street                 Visa
# 1243   132012      street     American_Express
# 1244   132012      street     bank_debit_cards
# 1245   132012      street          Diners_Club
#
# [1246 rows x 3 columns]

# %%
df3 = pd.read_csv("archive/geoplaces2.csv")

# %%
df3
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
merged_df_2 = pd.merge(merged_df, df3, left_on='placeID', right_on='placeID')
merged_df_2
# Out:
#      placeID parking_lot             Rpayment   latitude   longitude  \
# 0     135109        none                 cash  18.921785  -99.235350
# 1     135106        none                 cash  22.149709 -100.976093
# 2     135106        none                 VISA  22.149709 -100.976093
# 3     135106        none  MasterCard-Eurocard  22.149709 -100.976093
# 4     135104         yes                 cash  23.752982  -99.168434
# ..       ...         ...                  ...        ...         ...
# 248   132583        none                 VISA  18.922290  -99.234332
# 249   132583        none  MasterCard-Eurocard  18.922290  -99.234332
# 250   132583        none     bank_debit_cards  18.922290  -99.234332
# 251   132572         yes                 cash  22.141647 -100.992712
# 252   132560      public                 cash  23.752304  -99.166913
#
#                                         the_geom_meter  \
# 0    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# ...

# %%
df4 = pd.read_csv("archive/chefmozcuisine.csv")
df4
# Out:
#      placeID        Rcuisine
# 0     135110         Spanish
# 1     135109         Italian
# 2     135107  Latin_American
# 3     135106         Mexican
# 4     135105       Fast_Food
# ..       ...             ...
# 911   132005         Seafood
# 912   132004         Seafood
# 913   132003   International
# 914   132002         Seafood
# 915   132001   Dutch-Belgian
#
# [916 rows x 2 columns]

# %%
merged_df_3 = pd.merge(merged_df_2, df4, left_on='placeID', right_on='placeID')
merged_df_3
# Out:
#      placeID parking_lot             Rpayment   latitude   longitude  \
# 0     135109        none                 cash  18.921785  -99.235350
# 1     135106        none                 cash  22.149709 -100.976093
# 2     135106        none                 VISA  22.149709 -100.976093
# 3     135106        none  MasterCard-Eurocard  22.149709 -100.976093
# 4     135104         yes                 cash  23.752982  -99.168434
# ..       ...         ...                  ...        ...         ...
# 226   132583        none                 VISA  18.922290  -99.234332
# 227   132583        none  MasterCard-Eurocard  18.922290  -99.234332
# 228   132583        none     bank_debit_cards  18.922290  -99.234332
# 229   132572         yes                 cash  22.141647 -100.992712
# 230   132560      public                 cash  23.752304  -99.166913
#
#                                         the_geom_meter  \
# 0    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# ...

# %%
df5 = pd.read_csv("archive/chefmozhours4.csv")
df5
# Out:
#       placeID         hours                  days
# 0      135111  00:00-23:30;  Mon;Tue;Wed;Thu;Fri;
# 1      135111  00:00-23:30;                  Sat;
# 2      135111  00:00-23:30;                  Sun;
# 3      135110  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 4      135110  00:00-00:00;                  Sat;
# ...       ...           ...                   ...
# 2334   132012  12:00-22:00;                  Sun;
# 2335   132012  12:00-22:00;  Mon;Tue;Wed;Thu;Fri;
# 2336   132012  12:00-22:00;  Mon;Tue;Wed;Thu;Fri;
# 2337   132012  12:00-22:00;                  Sat;
# 2338   132012  12:00-22:00;                  Sat;
#
# [2339 rows x 3 columns]

# %%
merged_df_4 = pd.merge(merged_df_3, df5, left_on='placeID', right_on='placeID')
merged_df_4
# Out:
#      placeID parking_lot Rpayment   latitude   longitude  \
# 0     135109        none     cash  18.921785  -99.235350
# 1     135109        none     cash  18.921785  -99.235350
# 2     135109        none     cash  18.921785  -99.235350
# 3     135106        none     cash  22.149709 -100.976093
# 4     135106        none     cash  22.149709 -100.976093
# ..       ...         ...      ...        ...         ...
# 640   132572         yes     cash  22.141647 -100.992712
# 641   132572         yes     cash  22.141647 -100.992712
# 642   132560      public     cash  23.752304  -99.166913
# 643   132560      public     cash  23.752304  -99.166913
# 644   132560      public     cash  23.752304  -99.166913
#
#                                         the_geom_meter  \
# 0    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 1    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 2    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# ...

# %%
pip --version
# Out:
# pip 22.2.2 from /Users/tusharjindal/opt/anaconda3/lib/python3.9/site-packages/pip (python 3.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geocoder
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 5.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geocoder

# %%
def get_current_gps_coordinates():
    g = geocoder.ip('me')#this function is used to find the current information using our IP Add
    if g.latlng is not None: #g.latlng tells if the coordiates are found or not
        return g.latlng
    else:
        return None


coordinates = get_current_gps_coordinates()
if coordinates is not None:
    latitude, longitude = coordinates
    filtered_df_1 = merged_df_4[(merged_df_4['latitude'] < latitude+2)]
    filtered_df_2 = filtered_df_1[(filtered_df_1['latitude'] > latitude+2)]
    filtered_df_3 = filtered_df_2[(filtered_df_2['longitude'] < longitude+2)]
    filtered_df_4 = filtered_df_3[(filtered_df_3['longitude'] > longitude+2)]
    
    
else:
    print("Unable to retrieve your GPS coordinates.")
        
        
filtered_df_4
# Out:
# Empty DataFrame
# Columns: [placeID, parking_lot, Rpayment, latitude, longitude, the_geom_meter, name, address, city, state, country, fax, zip, alcohol, smoking_area, dress_code, accessibility, price, url, Rambience, franchise, area, other_services, Rcuisine, hours, days]
# Index: []
#
# [0 rows x 26 columns]

# %%
pip install git
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install npm
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for npm: filename=npm-0.1.1-py3-none-any.whl size=3685 sha256=f426459e003b1fbd998bcf4fc4c72995b4d716c0f4628ad431457358d520d267
#   Stored in directory: /Users/tusharjindal/Library/Caches/pip/wheels/a8/3d/20/136a3e3f50d4772622e0745143a716ecdbf6412f4d3f137a09
# ...
#   Created wheel for optional-django: filename=optional_django-0.1.0-py3-none-any.whl size=9952 sha256=ecd66a5fa74bc6dd0aa16c7c9c8fb7c71886a4c848baec1715ad2c6ee28f3b27
#   Stored in directory: /Users/tusharjindal/Library/Caches/pip/wheels/02/8b/80/98951377d9c707978a3798a23f2b260e00bcfc724073556cf4
# Successfully built npm optional-django
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install node
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 6.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge jupyterlab-git
# Out:
# Could not load conda plugin `anaconda-cloud-auth`:
#
# cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/Users/tusharjindal/opt/anaconda3/lib/python3.9/site-packages/conda/plugins/types.py)
# Retrieving notices: ...working... done
# ...
# done
# Solving environment: -
